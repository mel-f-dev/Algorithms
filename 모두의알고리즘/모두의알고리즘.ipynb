# %% [markdown]
# # 1부터 n까지 합

# %%
a = list(range(1,11))
sum(a)
# Out:
# 55

# %%
b = list(range(1, 101))
sum(b)
# Out:
# 5050

# %%
def sum(n):
    S = 0
    i = 1
    for i in range(1, n+1):
        S = S + i
    return S

# %%
print(sum(10))
print(sum(100))
# Out:
# 55
# 5050

# %%
def sum_n(n):
    return n*(n+1) // 2    # //: 정수 나눗셈

# %%
print(sum_n(10))
print(sum_n(100))
# Out:
# 55
# 5050

# %%
def sum_sq(n):
    S = 0
    for i in range(1, n+1):
        S += i**2
    return S

# %%
sum_sq(10)
# Out:
# 385

# %%
def find_min(a):
    n = len(a)
    min_v = a[1]
    for i in range(n):
        if a[i] < min_v:
            min_v = a[i]
    return min_v

# %%
a = [1, 3, 2, 0, 3, 2]
find_min(a)
# Out:
# 0

# %%
b = [23, 1, 30, -20, 2, 302, 7]
find_min(b)
# Out:
# -20

# %%
def find_same_name(a):
    n = len(a)
    result = set()
    for i in range(0, n-1):
        for j in range(i+1, n):
            if a[i] == a[j]:
                result.add(a[j])
    return result

# %%
name = ["Tom", "Jerry", "Mike", "Tom"] # 대소문자 유의: 파이썬은 대소문자를 구분함

print(find_same_name(name))

name2 = ["Tom", "Jerry", "Mike", "Tom", 'Mike']

print(find_same_name(name2))
# Out:
# {'Tom'}
# {'Mike', 'Tom'}

# %%
def pair(a):
    n = len(a)
    for i in range(n-1):
        for j in range(i+1, n):
            print(f'{a[i]} - {a[j]}')

# %%
a = ["Tom", "Jerry", "Mike"]
pair(a)
# Out:
# Tom - Jerry
# Tom - Mike
# Jerry - Mike

# %%
import re
p = re.compile('[a-z]+')
m = p.match( 'string goes here' )
if m:
    print('Match found: ', m.group())
else:
    print('No match')
# Out:
# Match found:  string

# %%
m = p.match("python")
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# python
# 0
# 6
# (0, 6)

# %% [markdown]
# # 팩토리얼 구하기

# %%
def fac(n):
    T = 1
    for i in range(1, n+1):
        T *= i
    return T

# %%
fac(5)
# Out:
# 120

# %% [markdown]
# # 재귀호출

# %%
def hello():
    print("hello")
    hello()

# %%
# 정상작동을 위해 종료조건 필요
# 특정조건이 되면 멈추도록 if not 재귀 에러(recursion Error)

# %%
def fact(n):
    if n <= 1:
        return 1
    return n * fact(n-1)

print(fact(1))
print(fact(5))
print(fact(10))
# Out:
# 1
# 120
# 3628800

# %%
# 1부터 n까지 합 재귀호출로
def rec_sum(n):
    if n < 1:
        return 0
    return n+rec_sum(n-1)

# %%
rec_sum(10)
# Out:
# 55

# %%
# 숫자 n개 중 최댓값 찾기 재귀호출로
def find_max(a): # 리스트 a의 앞부분 n개 중 최댓값 구하는 재귀함수
    n = len(a)
    
    if n == 1:
        return a[0]
    
    max_n_1 = find_max(a[:n-1]) # 리스트 a의 앞부분 n-1개 중 최댓값
    if max_n_1 > a[n-1]:    # n-1개 중 최댓값과 n-1번 위치값 비교
        return max_n_1
    else:
        return a[n-1]

# %%
v = [17, 92, 18, 33, 58, 7, 33, 42]

# %%
find_max(v)
# Out:
# 92

# %%
# a와 b의 최대공약수

# 1 | 두 수 중 더 작은 값을 i에 저장합니다.

# 2 | i가 두 수의 공통된 약수인지 확인합니다.

# 3 | 공통된 약수이면 이 값을 결괏값으로 돌려주고 종료합니다.

# 4 | 공통된 약수가 아니면 i를 1만큼 감소시키고 2번으로 돌아가 반복합니다(1은 모든 정수의 약수이므로 i가 1이 되면 1을 결괏값으로 돌려주고 종료합니다).

 

def gcd(a, b):
    i = min(a, b)
    while True:
        if a % i == 0 and b % i == 0:
            return i
        i -= 1

# %%
print(gcd(1, 5))
print(gcd(3, 6))
print(gcd(60, 24))
print(gcd(81, 27))
# Out:
# 1
# 3
# 12
# 27

# %%
# 유클리드 알고리즘
# • a와 b의 최대공약수는 ‘b’와 ‘a를 b로 나눈 나머지’의 최대공약수와 같습니다. 즉, gcd(a, b) = gcd(b, a % b)입니다.
# • 어떤 수와 0의 최대공약수는 자기 자신입니다. 즉, gcd(n, 0) = n입니다.

def euclid_gcd(a, b):
    if b == 0:    # 종료 조건
        return a
    return euclid_gcd(b, a % b)    # 좀 더 작은 값으로 자기 자신 호출

# %%
print(euclid_gcd(1, 5))          # 1

print(euclid_gcd(3, 6))          # 3

print(euclid_gcd(60, 24))        # 12

print(euclid_gcd(81, 27))        # 27
# Out:
# 1
# 3
# 12
# 27

# %%
# 피보나치 수열

def fibo(n):
    if n <= 1:
        return n 
    return fibo(n-2) + fibo(n-1)

# %%
print(fibo(7))
print(fibo(10))
# Out:
# 13
# 55

# %%
# 하노이의 탑 옮기기
# 원반 n개, 원반 이동 순서 출력

def hanoi(n, from_pos, to_pos, aux_pos):
    if n == 1:
        print(from_pos, "->", to_pos)
        return
    
    # 원반 n-1개를 aux_pos로 이동(to_pos를 보조 기둥으로)
    hanoi(n-1, from_pos, aux_pos, to_pos)
    # 가장 큰 원반을 목적지로 이동
    print(from_pos, "->", to_pos)
    # aux_pos에 있는 원반 n-1개를 목적지로 이동(from_pos를 보조 기둥으로)
    hanoi(n-1, aux_pos, to_pos, from_pos)

# %%
print("n = 1")

hanoi(1, 1, 3, 2) # 원반 한 개를 1번 기둥에서 3번 기둥으로 이동(2번을 보조 기둥으로)
# Out:
# n = 1
# 1 -> 3

# %%
print("n = 2")

hanoi(2, 1, 3, 2)
# Out:
# n = 2
# 1 -> 2
# 1 -> 3
# 2 -> 3

# %%
print("n = 20")

hanoi(20, 1, 3, 2)
# Out:
# n = 20
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 3 -> 1
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 3 -> 1
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 3 -> 1
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 3 -> 1
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 3 -> 1
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 1 -> 2
# 3 -> 1
# 3 -> 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# 2 -> 1
# 3 -> 1
# 2 -> 3
# 1 -> 2
# 1 -> 3
# ...

# %%
import turtle as t

# %%
def spiral(sp_len):

    if sp_len <= 5:

        return

    t.forward(sp_len)

    t.right(90)

    spiral(sp_len - 5)

 

t.speed(0)

spiral(200)

t.hideturtle()

t.done()

# %%
def tri(tri_len):

    if tri_len <= 10:

        for i in range(0, 3):

            t.forward(tri_len)

            t.left(120)

        return

    new_len = tri_len / 2

    tri(new_len)

    t.forward(new_len)

    tri(new_len)

    t.backward(new_len)

    t.left(60)

    t.forward(new_len)

    t.right(60)

    tri(new_len)

    t.left(60)

    t.backward(new_len)

    t.right(60)

 

t.speed(0)

tri(160)

t.hideturtle()

t.done()

# %%
def tree(br_len):

    if br_len <= 5:

        return

    new_len = br_len * 0.7

    t.forward(br_len)

    t.right(20)

    tree(new_len)

    t.left(40)

    tree(new_len)

    t.right(20)

    t.backward(br_len)

 

t.speed(0)

t.left(90)

tree(70)

t.hideturtle()

t.done()

# %%
def snow_line(snow_len):

    if snow_len <= 10:

        t.forward(snow_len)

        return

    new_len = snow_len / 3

    snow_line(new_len)

    t.left(60)

    snow_line(new_len)

    t.right(120)

    snow_line(new_len)

    t.left(60)

    snow_line(new_len)

 

t.speed(0)

snow_line(150)

t.right(120)

snow_line(150)

t.right(120)

snow_line(150)

t.hideturtle()

t.done()

# %%
# 순차탐색: 하나씩 순차적으로 비교하면서 탐색, 선형탐색
# 주어진 리스트에 특정한 값이 있는지 찾아 그 위치를 돌려주는 알고리즘을 만들어 보세요. 리스트에 찾는 값이 없다면 -1

# a: 리스트, x: 찾는 값
def search_list(a, x):
    n = len(a)
    for i in range(0, n):
        if x == a[i]:
            return i
        
    return -1    # 끝까지 비교해도 없으면 -1

# %%
v = [17, 92, 18, 33, 58, 5, 33, 42]
print(search_list(v, 18))
print(search_list(v, 33))    # 처음 나온 위치만 출력
print(search_list(v, 900))
# Out:
# 2
# 3
# -1

# %%
# 찾는 값이 모두 나오는 탐색 알고리즘
def search_list(a, x):
    re_list = []
    n = len(a)
    for i in range(n):
        if x == a[i]:
            re_list.append(i)
    return re_list

# %%
print(search_list(v, 33))    
# print(search_list(v, 900))
# Out:
# [3, 6]

# %%
def search_num(num):
    for i in range(len(stu_no)):
        if num == stu_no[i]:
            return stu_name[i]
        
    return "?"    # 자료에서 못 찾으면

# %%
stu_no = [39, 14, 67, 105]
stu_name = ["“Justin”", "“John”", "“Mike”", "“Summer”"]

# %%
print(search_num(39))
print(search_num(14))
print(search_num(67))
print(search_num(105))
# Out:
# “Justin”
# “John”
# “Mike”
# “Summer”

# %%
def get_name(s_no, s_name, find_no):

    n = len(s_no)               # 입력 크기 n

    for i in range(0, n):

        if find_no == s_no[i]: # 학생 번호가 찾는 학생 번호와 같으면

            return s_name[i]    # 해당하는 학생 이름을 결과로 반환

 

    return "?"                  # 자료를 다 뒤져서 못 찾았으면 물음표 반환

 

sample_no = [39, 14, 67, 105]

sample_name = ["Justin", "John", "Mike", "Summer"]

print(get_name(sample_no, sample_name, 105))

print(get_name(sample_no, sample_name, 777))
# Out:
# Summer
# ?
